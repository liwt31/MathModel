# %% [markdown]
# # Drawing Phase Plane for System of Ordinary Differential Equations

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.style.use("mm.mplstyle")

# %% [markdown]
# ## Competitive predator model
#
# $$
# \frac{dx}{dt} = ax-bxy
# $$
#
# $$
# \frac{dy}{dt} = my - nxy
# $$

# %%
a = 1
b = 1
m = 1
n = 1

# %%
x = np.linspace(0, 3)
y = np.linspace(0, 3)

u = a * x.reshape(1, -1) - b * x.reshape(1, -1) * y.reshape(-1, 1)
v = m * y.reshape(-1, 1) - n * x.reshape(1, -1) * y.reshape(-1, 1)

# %%
plt.streamplot(x, y, u, v, broken_streamlines=False, density=0.5)
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %% [markdown]
# Problems
# - Eqiulibrium points and their stability?
# - Meaning of $a$, $b$, $m$ and $n$?

# %% [markdown]
# ## Predator and pray model
# $$
# \frac{dx}{dt} = ax-bxy
# $$
#
# $$
# \frac{dy}{dt} = - my + nxy
# $$

# %%
a = 1
b = 1
m = 1
n = 1

# %%
x = np.linspace(0, 3)
y = np.linspace(0, 3)

u = a * x.reshape(1, -1) - b * x.reshape(1, -1) * y.reshape(-1, 1)
v = -m * y.reshape(-1, 1) + n * x.reshape(1, -1) * y.reshape(-1, 1)

# %%
plt.streamplot(x, y, u, v, broken_streamlines=False, density=0.5)
plt.xlabel("$x$ (Krill)")
plt.ylabel("$y$ (Whale)")
plt.show()

# %% [markdown]
# Problems
# - Eqiulibrium points and their stability?
# - Meaning of $a$, $b$, $m$ and $n$?
